# %% [markdown]
# <a href="https://colab.research.google.com/github/NsGp-dr/Cursillo-Python/blob/main/Python_para_Dummies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python para Dummies (Cursillo)**
# Universidad Distrital Francisco José de Caldas\
# Nicolás Santiago Giraldo Parra (*nsgiraldop@udistrital.edu.co*)\
# Estudiante de Matemáticas

# %% [markdown]
# ## **Programación, ¿Qué es?, ¿Cómo se come? 🤨👨‍💻👩‍💻**
#
#
# ![pragraación2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# La programación es la creación de **instrucciones**, en un lenguaje que un ordenador puede entender.
#
# **¡Python** es uno de esos lenguajes!

# %% [markdown]
# ### ¿Qué es un *IDE* 💻?

# %% [markdown]
# ![IDE.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **IDE** : Entorno de Desarrollo Integrado (integrated development environment)\
#
# Es donde ocurre la magia, normalmente los programadores trabajan con editores de código y con IDEs, la diferencia entre estos dos cuando hacemos trabajos pequeños no es mucha, el editor sirve para hacer archivos y el IDE para hacer proyectos grandes de inicio a fin que contienen bastantes archivos.

# %% [markdown]
# ## **Python 🐍**

# %% [markdown]
# **Python** 🐍 es uno de los lenguajes de programación **más populares**. Permite crear **juegos**, **aplicaciones** ¡Incluso **sitios web**!, sirve para un montón de cosas, se usa principalmente en las **ciencias** 👩‍🔬, **Python** es el lenguaje más utilizado para la **Inteligencia Artificial**.

# %% [markdown]
# ### **Variables** 📦

# %% [markdown]
#   **¿Serán como las variables en matemáticas?**
#
#
# Piensa en las variables como cajas donde puedes guardar diferentes tipos de datos. Puedes etiquetar estas cajas con un nombre para recordarte qué tipo de datos has guardado en cada una. Por ejemplo, si tienes una caja etiquetada como "edad", puedes guardar un número en ella que represente la edad de alguien.
#
# En Python, una variable se define simplemente dando un nombre a la variable y asignándole un valor usando el signo =. Por ejemplo:
# ```
#     edad = 20  # Aquí, la variable "edad" guarda el número 20
#     nombre = "Ana"  # La variable "nombre" guarda el texto "Ana"
# ```

# %% [markdown]
# **Tipos de datos en Python:**

# %% [markdown]
# Python tiene varios tipos de datos que puedes guardar en las variables. Aquí te explico los más comunes:
#
# *   Strings (Cadenas de texto):\
# Los strings son textos o cadenas de caracteres. Se representan con comillas simples ' o comillas dobles ".
#
#     Ejemplo:
# ```
#     saludo = "Hola"  # Un string que contiene la palabra "Hola"
# ```
#
# *   Números (int, float, ...):\
#     Python maneja diferentes tipos de números:
#
#     Enteros (int): Son números enteros sin decimales.
#     Ejemplo:
# ```
#     edad = 25  # Un número entero
# ```
#     Flotantes (float): Son números con decimales.
#     Ejemplo:
# ```
#     precio = 19.99  # Un número con decimales
# ```

# %%
# con el símbolo # podemos hacer comentarios que Python no leerá
x = 5
print(type(x))  # Muestra <class 'int'>, indicando que x es un entero

y = "Hola"
print(type(y))  # Muestra <class 'str'>, indicando que y es un string
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### **Funciones Básicas** 👾
#
# **'print' en Python:**
#
# La función print es una función muy común en Python que se usa para **mostrar información en la pantalla**. Puedes usarla para mostrar mensajes, valores de variables o cualquier otra información que quieras que el usuario vea.

# %%
#Mostrar mensajes
print("¡Hola, mundo!")
# Out:
# ¡Hola, mundo!

# %%
#Mostrar el valor de una Variable
edad = 20
print("Edad:", edad)
# Out:
# Edad: 20

# %%
#Mostrar varios valores a la vez
nombre = "Ana"
edad = 25
print("Nombre:", nombre, "Edad:", edad)
# Out:
# Nombre: Ana Edad: 25

# %% [markdown]
# **'input' en Python:**
#
# La función input se usa para **pedir datos al usuario**. Cuando se ejecuta input, se detiene el programa hasta que el usuario ingrese algún dato y presione Enter. **El valor que el usuario ingresa se guarda como un string.**

# %%
#Pedir un string al usuario
nombre = input("Por favor, ingresa tu nombre: ")
print("Hola, " + nombre + "!")
# Out:
# Por favor, ingresa tu nombre: Nicolás
# Hola, Nicolás!

# %%
#Pedir un número al usuario
edad = input("Por favor, ingresa tu edad: ")
edad = int(edad)  # Convierte el string a entero
print("Tienes", edad, "años.")
# Out:
# Por favor, ingresa tu edad: 21
# Tienes 21 años.

# %% [markdown]
# ### **Operadores Básicos** ✖️ ➕ ➖

# %% [markdown]
# **Numéricos**
# ```
# + : adición
# - : resta
# * : multiplicación
# / : división
# // : división de enteros
# ** : potenciación
# % : módulo
# ```
# **Lógicos**
# ```
# < : división
# > : división de enteros
# <= : potenciación
# >= : módulo
# == : potenciación
# != : módulo
#
# ```

# %% [markdown]
# **Ejemplo Operadores Numéricos**

# %%
print(2+5)
print(2-5)
print(2*5)
print(2/5)
print(2//5)
print(2**5)
print(5%2)
# Out:
# 7
# -3
# 10
# 0.4
# 0
# 32
# 1

# %% [markdown]
# **Ejemplo Operadores Lógicos**

# %%
print(2>5)
print(2<5)
print(2>=5)
print(2<=5)
print(2==2)
print(2!=5)
# Out:
# False
# True
# False
# True
# True
# True

# %% [markdown]
# ### **Condicionales** ✔️❌

# %% [markdown]
# *    **if** y **else**\
# Los condicionales en Python te permiten tomar decisiones basadas en condiciones específicas. Puedes usar la palabra clave **if** para evaluar una condición y ejecutar un bloque de código si la condición es verdadera ✔️.\
# También puedes usar **else** para ejecutar un bloque de código si la condición de if es falsa ❌.

# %% [markdown]
# ```
# # Sintaxis básica de un condicional
# if condición:
#     # Bloque de código si la condición es verdadera
# else:
#     # Bloque de código si la condición es falsa
#
# ```

# %% [markdown]
# **Ejemplo Condicionales (if - else)**

# %%
edad = int(input("¿Qué edad tienes?"))

if edad >= 18:
    print("Eres mayor de edad.")
else:
    print("Eres menor de edad.")
# Out:
# ¿Qué edad tienes?21
# Eres mayor de edad.

# %% [markdown]
# ## **Resumen:**
# **Variables** Funcionan como una caja, almacenan datos.\
# **print** se usa para mostrar información en la pantalla.\
# **input** se usa para pedir información al usuario.\
# **Condicionales:**
#   *     Usa if para evaluar una condición y ejecutar un bloque de código si la condición es verdadera.
#
#   *     Usa else para ejecutar un bloque de código alternativo si la condición de if es falsa.
